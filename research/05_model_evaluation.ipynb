# %%
import os

# %%
pwd
# Out:
# '/home/satyam/Wine-Quality-Prediction/research'

# %%
os.chdir('../')

# %%
pwd
# Out:
# '/home/satyam/Wine-Quality-Prediction'

# %%
import mlflow
import dagshub

dagshub.init(repo_owner='SatyamKumar457', repo_name='Wine-Quality-Prediction', mlflow=True)
with mlflow.start_run():
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import mlflow
#       2 import dagshub
#       4 dagshub.init(repo_owner='SatyamKumar457', repo_name='Wine-Quality-Prediction', mlflow=True)
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/__init__.py:41
#      38 warnings.filterwarnings("ignore", message="numpy.dtype size changed")
#      39 warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# ---> 41 from mlflow import projects  # pylint: disable=unused-import
#      42 from mlflow import tracking  # pylint: disable=unused-import
#      43 from mlflow import models  # pylint: disable=unused-import
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/projects/__init__.py:28
#      13 from mlflow.projects.submitted_run import SubmittedRun
#      14 from mlflow.projects.utils import (
#      15     PROJECT_SYNCHRONOUS,
#      16     get_entry_point_command,
#    (...)
#      26     PROJECT_DOCKER_AUTH,
#      27 )
# ---> 28 from mlflow.projects.backend import loader
#      29 from mlflow.tracking.fluent import _get_experiment_id
#      30 from mlflow.utils.mlflow_tags import (
#      31     MLFLOW_PROJECT_ENV,
#      32     MLFLOW_PROJECT_BACKEND,
#      33     MLFLOW_RUN_NAME,
#      34     MLFLOW_DOCKER_IMAGE_ID,
#      35 )
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/projects/backend/loader.py:4
#       1 import entrypoints
#       2 import logging
# ----> 4 from mlflow.projects.backend.local import LocalBackend
#       7 ENTRYPOINT_GROUP_NAME = "mlflow.project_backend"
#       9 __logger__ = logging.getLogger(__name__)
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/projects/backend/local.py:32
#      30 from mlflow.utils.environment import _PythonEnv
#      31 from mlflow.utils.conda import get_or_create_conda_env
# ---> 32 from mlflow.utils.virtualenv import (
#      33     _install_python,
#      34     _create_virtualenv,
#      35     _get_virtualenv_name,
#      36     _get_mlflow_virtualenv_root,
#      37     _get_virtualenv_extra_env_vars,
#      38     _VIRTUALENV_ENVS_DIR,
#      39     _PYENV_ROOT_DIR,
#      40 )
#      41 from mlflow.store.artifact.artifact_repository_registry import get_artifact_repository
#      42 from mlflow.store.artifact.azure_blob_artifact_repo import AzureBlobArtifactRepository
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/utils/virtualenv.py:11
#       9 import mlflow
#      10 from mlflow.exceptions import MlflowException
# ---> 11 from mlflow.models.model import Model, MLMODEL_FILE_NAME
#      12 from mlflow.utils.file_utils import TempDir
#      13 from mlflow.utils.process import _exec_cmd, _join_commands, _IS_UNIX
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/models/__init__.py:23
#       1 """
#       2 The ``mlflow.models`` module provides an API for saving machine learning models in
#       3 "flavors" that can be understood by different downstream tools.
#    (...)
#      20 For details, see `MLflow Models <../models.html>`_.
#      21 """
# ---> 23 from .model import Model, get_model_info
#      24 from .flavor_backend import FlavorBackend
#      25 from ..utils.environment import infer_pip_requirements
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/models/model.py:242
#     202         """
#     203         User defined metadata added to the model.
#     204
#    (...)
#     237             assert model_info.metadata["metadata_key"] == "metadata_value"
#     238         """
#     239         return self._metadata
# --> 242 class Model:
#     243     """
#     244     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     245     new Model flavors.
#     246     """
#     248     def __init__(
#     249         self,
#     250         artifact_path=None,
#    (...)
#     260     ):
#     261         # store model id instead of run_id and path to avoid confusion when model gets exported
#
# File ~/Wine-Quality-Prediction/venv/lib/python3.10/site-packages/mlflow/models/model.py:257, in Model()
#     242 class Model:
#     243     """
#     244     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     245     new Model flavors.
#     246     """
#     248     def __init__(
#     249         self,
#     250         artifact_path=None,
#     251         run_id=None,
#     252         utc_time_created=None,
#     253         flavors=None,
#     254         signature=None,  # ModelSignature
#     255         saved_input_example_info: Dict[str, Any] = None,
#     256         model_uuid: Union[str, Callable, None] = lambda: uuid.uuid4().hex,
# --> 257         mlflow_version: Union[str, None] = mlflow.version.VERSION,
#     258         metadata: Optional[Dict[str, Any]] = None,
#     259         **kwargs,
#     260     ):
#     261         # store model id instead of run_id and path to avoid confusion when model gets exported
#     262         if run_id:
#     263             self.run_id = run_id
#
# AttributeError: partially initialized module 'mlflow' has no attribute 'version' (most likely due to a circular import)
